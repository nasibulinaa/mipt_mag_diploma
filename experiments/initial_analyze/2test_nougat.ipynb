# %%
# !pip install nougat-ocr nougat-ocr[api] albumentations==1.0.0 albucore==0.0.16 transformers==4.38.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 582.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 13.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 74.3 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.24
#     Uninstalling albucore-0.0.24:
#       Successfully uninstalled albucore-0.0.24
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# ...

# %%
# !nougat tests_pdfs/t1.pdf -o output_directory -m 0.1.0-base
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /home/alexey/test/.venv-nougat/lib/python3.12/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|                                                     | 0/1 [00:00<?, ?it/s]ERROR:root:'PdfDocument' object has no attribute 'render'
# ERROR:root:list index out of range
# ERROR:root:list index out of range
# ERROR:root:list index out of range
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# Traceback (most recent call last):
# ...

# %%
from PIL import Image
from IPython.display import display, Math

for img in list(Path("test_images").glob("*.png")):
    image = Image.open(img)
    print(f"Processing image: {img}")
    text = model(image)
    print(f"Extracted LaTeX: {text}")
    display(Math(text))

# %%
docker run -it --gpus all xiaoyao9184/nougat:main

# %% [markdown]
# root@75f33cc1abf6:/app# nougat /t1.pdf -o output_directory -m 0.1.0-small --no-markdown
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /app/nougat/transforms.py:146: UserWarning: Argument 'alpha_affine' is not valid and will be ignored.
#   alb.ElasticTransform(
# INFO:root:Output directory does not exist. Creating output directory.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1716905971132/work/aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|                                                                                                                                                                                                                                                                                                                                                                                                   | 0/1 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1716905971132/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# /app/nougat/model.py:437: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /opt/conda/conda-bld/pytorch_1716905971132/work/aten/src/ATen/native/ReduceOps.cpp:1807.)
#   return torch.var(self.values, 1) / self.values.shape[1]
# WARNING:root:Found repetitions in sample 0
# INFO:root:Processing file /t1.pdf with 3 pages
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.89s/it]
# root@75f33cc1abf6:/app# cat t
# test.py   train.py
# root@75f33cc1abf6:/app# cat output_directory/t1.mmd
# [MISSING_PAGE_EMPTY:1]
#
# 2. \(\beta_{1}=(xyx)^{t};\ \gamma=(xyx)^{q}x;\ \beta_{2}=yx(xyx)^{n-t-q-1}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-1\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}yx(xyx)^{n-t-q-1}( yxy)^{n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)
# 3. \(\beta_{1}=(xyx)^{t};\ \gamma=(xyx)^{q}xy;\ \beta_{2}=x(xyx)^{n-t-q-1}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-1\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}x(xyx)^{n-t-q-1}( yxy)^{n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)
# 4. \(\beta_{1}=(xyx)^{t}x;\ \gamma=yx(xyx)^{q};\ \beta_{2}=(xyx)^{n-t-q-1}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-1\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}x(xyx)^{n-t-q-1}( yxy)^{n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)
# 5. \(\beta_{1}=(xyx)^{t}x;\ \gamma=yx(xyx)^{q}x;\ \beta_{2}=yx(xyx)^{n-t-q-2}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-2\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{n-q-1}(yxy)^{n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)
# 6. \(\beta_{1}=(xyx)^{t}x;\ \gamma=yx(xyx)^{q}xy;\ \beta_{2}=x(xyx)^{n-t-q-2}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-2\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}xx(xyx)^{n-t-2}(yxy)^ {n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)
# 7. \(\beta_{1}=(xyx)^{t}xy;\ \gamma=x(xyx)^{q};\ \beta_{2}=(xyx)^{n-t-q-1}.\) Pri atom \(q\geq 0;\)\(t\geq 0;\ n-t-q-1\geq 0.\) To lemme o nakachke slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}xy(xyx)^{n-t-q-1}( yxy)^{n}\] prnadlezhit zykh, onaka, \(\hat{\imath}\)to ne verno, t.k. slovo ne prnadlezhit zykh \(\Phi.\)8. \(\beta_{1}=(xyx)^{t}xy;\;\gamma=x(xyx)^{q}x;\;\beta_{2}=yx(xyx)^{n-t-q-2}.\) Pari atom \(q\geq 0;\;t\geq 0;\;n-t-q-2\geq 0.\) Plolemme o nakakake slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{t}xyyx(xyx)^{n-t-q-2}( yxy)^{n}\] prnnadlezhkt znykh, odnako, zto ne verno, t.k. slovo ne prnadlezhkt znykh \(\Phi.\)
# 9. \(\beta_{1}=(xyx)^{t}xy;\;\gamma=x(xyx)^{q}xy;\;\beta_{2}=x(xyx)^{n-t-q-2}.\) Pari atom \(q\geq 0;\;t\geq 0;\;n-t-q-2\geq 0.\) Plolemme o nakakake slovo: \[\alpha_{1}\beta_{1}\gamma^{0}\beta_{2}\alpha_{2}=(xyx)^{n-q-1}(yxy)^{n}\] prnadlezhkt znykh, odnako, v atom slove \((xyx)\) vstrechaetsia minimum na 1 raz menyche, chem \((xyy),\) sledovatel'no zto slovo ne mozket prnadlezhkt znykh \(\Phi.\)
#
# See rascmotrennye slucha prnyeli k prnovorechio, sledovatel'no iskodnoe predlolozhenie byllo zokhivm, i iznykh \(\Phi\) ne znykh \(\Phi\) ne znykh \(\Phi\)root@75f33cc1abf6:/app#
