# %%
# !pip install rapid_latex_ocr requests
# Out:
# Requirement already satisfied: rapid_latex_ocr in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (0.0.9)
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: onnxruntime in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (1.23.2)
# Requirement already satisfied: tokenizers>=0.13.2 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (0.22.1)
# Requirement already satisfied: numpy<2.0.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (1.26.4)
# Requirement already satisfied: opencv-python in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (4.11.0.86)
# Requirement already satisfied: Pillow>=9.2.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (12.0.0)
# Requirement already satisfied: PyYAML in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (6.0.3)
# Requirement already satisfied: chardet in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from rapid_latex_ocr) (5.2.0)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from tokenizers>=0.13.2->rapid_latex_ocr) (1.0.1)
# Requirement already satisfied: coloredlogs in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from onnxruntime->rapid_latex_ocr) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from onnxruntime->rapid_latex_ocr) (25.9.23)
# Requirement already satisfied: packaging in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from onnxruntime->rapid_latex_ocr) (25.0)
# Requirement already satisfied: protobuf in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from onnxruntime->rapid_latex_ocr) (6.33.0)
# Requirement already satisfied: sympy in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from onnxruntime->rapid_latex_ocr) (1.14.0)
# Requirement already satisfied: filelock in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (2025.10.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (0.28.1)
# Requirement already satisfied: shellingham in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (4.67.1)
# Requirement already satisfied: typer-slim in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from coloredlogs->onnxruntime->rapid_latex_ocr) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from sympy->onnxruntime->rapid_latex_ocr) (1.3.0)
# Requirement already satisfied: anyio in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (8.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv-RapidLaTeXOCR/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->rapid_latex_ocr) (1.3.1)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Installing collected packages: urllib3, charset_normalizer, requests
# Successfully installed charset_normalizer-3.4.4 requests-2.32.5 urllib3-2.5.0

# %%
from pathlib import Path
from rapid_latex_ocr import LaTeXOCR

model = LaTeXOCR()

for img in list(Path("test_images").glob("*.png")):
    print(f"Processing image: {img}")
    with open(img, "rb") as f:
        data = f.read()
    res, elapse = model(data)
    print(f"Extracted LaTeX ({elapse}): {res}")
    display(Math(res))
# Out:
# Processing image: test_images/t1_page_1.png
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py:117, in LaTeXOCR.__call__(self, img)
#     116 try:
# --> 117     resizered_img = self.loop_image_resizer(img)
#     118 except Exception as e:
#
# File ~/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py:145, in LaTeXOCR.loop_image_resizer(self, img)
#     144 h = int(h * r)
# --> 145 final_img, pad_img = self.pre_process(input_image, r, w, h)
#     147 resizer_res = self.image_resizer([final_img.astype(np.float32)])[0]
#
# File ~/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py:165, in LaTeXOCR.pre_process(self, input_image, r, w, h)
#     163     resize_func = Image.Resampling.LANCZOS
# --> 165 resize_img = input_image.resize((w, h), resize_func)
#     166 pad_img = self.pre_pro.pad(self.pre_pro.minmax_size(resize_img))
#
# File ~/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/PIL/Image.py:2304, in Image.resize(self, size, resample, box, reducing_gap)
#    2297         box = (
#    2298             (box[0] - reduce_box[0]) / factor_x,
#    2299             (box[1] - reduce_box[1]) / factor_y,
#    2300             (box[2] - reduce_box[0]) / factor_x,
#    2301             (box[3] - reduce_box[1]) / factor_y,
#    2302         )
# -> 2304 return self._new(self.im.resize(size, resample, box))
#
# MemoryError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       8 with open(img, "rb") as f:
#       9     data = f.read()
# ---> 10 res, elapse = model(data)
#      11 print(f"Extracted LaTeX ({elapse}): {res}")
#      12 display(Math(res))
#
# File ~/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py:120, in LaTeXOCR.__call__(self, img)
#     118 except Exception as e:
#     119     error_info = traceback.format_exc()
# --> 120     raise ValueError(
#     121         f"image resizer meets error. Error info is {error_info}"
#     122     ) from e
#     124 try:
#     125     dec = self.encoder_decoder(resizered_img, temperature=self.temperature)
#
# ValueError: image resizer meets error. Error info is Traceback (most recent call last):
#   File "/home/alexey/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py", line 117, in __call__
#     resizered_img = self.loop_image_resizer(img)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alexey/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py", line 145, in loop_image_resizer
#     final_img, pad_img = self.pre_process(input_image, r, w, h)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alexey/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/rapid_latex_ocr/main.py", line 165, in pre_process
#     resize_img = input_image.resize((w, h), resize_func)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alexey/test/.venv-RapidLaTeXOCR/lib/python3.12/site-packages/PIL/Image.py", line 2304, in resize
#     return self._new(self.im.resize(size, resample, box))
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# MemoryError
