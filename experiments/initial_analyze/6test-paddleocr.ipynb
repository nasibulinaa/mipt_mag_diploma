# %%
#!pip3 install paddleocr[all]
# !pip3 install paddlepaddle-gpu==3.2.1 --upgrade -i https://www.paddlepaddle.org.cn/packages/stable/cu129/
# Out:
# Looking in indexes: https://www.paddlepaddle.org.cn/packages/stable/cu129/
# ...

# %%
# Initialize PaddleOCR instance
from paddleocr import PaddleOCR
ocr = PaddleOCR(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False,
    lang='ru')

# Run OCR inference on a sample image 
result = ocr.predict(
    input="test_images/t1_page_1.png")

# Visualize the results and save the JSON results
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/home/alexey/.paddlex/official_models/PP-OCRv5_server_det`.
# Creating model: ('eslav_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/home/alexey/.paddlex/official_models/eslav_PP-OCRv5_mobile_rec`.
# {'res': {'input_path': 'test_images/t1_page_1.png', 'page_index': None, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': array([[[ 589,  546],
#         ...,
#         [ 589,  595]],
#
#        ...,
#
#        [[1256, 2877],
#         ...,
# ...

# %%
from IPython.display import display, Math, Image

display(Image("output/t1_page_1_ocr_res_img.png"))
