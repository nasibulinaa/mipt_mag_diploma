# %%
# %pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.1.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 287.2 kB/s eta 0:00:00a 0:00:01
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Downloading regex-2026.1.15-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 2.4 MB/s eta 0:00:00a 0:00:01m
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.2 regex-2026.1.15 tqdm-4.67.3
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import difflib
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

words1, words2 = ["примеры", "тестим", "маJIинное", "обучение"], ["пример0в", "тест", "машина", "обучаться"]
stem_words1, stem_words2 = [stemmer.stem(word) for word in words1],  [stemmer.stem(word) for word in words2]
for word in stem_words1:
    print(f"Word: {word}, Closest: {difflib.get_close_matches(word, stem_words2, cutoff=0.7)}")
# Out:
# Word: пример, Closest: ['пример0в']
# Word: тест, Closest: ['тест']
# Word: маJIин, Closest: ['машин']
# Word: обучен, Closest: ['обуча']
