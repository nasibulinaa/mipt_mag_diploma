# %%
# !git clone -b v1.4.9.8 https://github.com/HKUDS/LightRAG.git
# !cd LightRAG; cp env.example .env
# Out:
# Cloning into 'LightRAG'...
# remote: Enumerating objects: 33314, done.
# remote: Counting objects: 100% (828/828), done.
# remote: Compressing objects: 100% (306/306), done.
# remote: Total 33314 (delta 655), reused 527 (delta 522), pack-reused 32486 (from 2)
# Receiving objects: 100% (33314/33314), 81.08 MiB | 7.68 MiB/s, done.
# Resolving deltas: 100% (24047/24047), done.
# Note: switching to '5bcd2926caf0a31dc52572108263a840b8d65aa3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# !ollama pull qwen3:4b
# !ollama pull bge-m3:latest
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 3e4cb1417446: 100% ▕██████████████████▏ 2.5 GB
# pulling 2d54db2b9bb2: 100% ▕██████████████████▏ 1.5 KB
# pulling d18a5cc71b84: 100% ▕██████████████████▏  11 KB
# pulling cff3f395ef37: 100% ▕██████████████████▏  120 B
# pulling e18a783aae55: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling daec91ffb5dd: 100% ▕██████████████████▏ 1.2 GB
# pulling a406579cd136: 100% ▕██████████████████▏ 1.1 KB
# pulling 0c4c9c2a325f: 100% ▕██████████████████▏  337 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# Paste it to `.env`:
#
# ```
# LLM_BINDING=ollama
# LLM_MODEL=qwen3:0.6b
# LLM_BINDING_HOST=http://localhost:11434
# #LLM_BINDING_API_KEY=your_api_key
#
# # EMBEDDING_TIMEOUT=30
# EMBEDDING_BINDING=ollama
# EMBEDDING_MODEL=bge-m3:latest
# EMBEDDING_DIM=1024
# #EMBEDDING_BINDING_API_KEY=your_api_key
# # If LightRAG deployed in Docker uses host.docker.internal instead of localhost
# EMBEDDING_BINDING_HOST=http://localhost:11434
# ```

# %%
# !pip install "lightrag-hku[api]"
# !cd LightRAG; lightrag-server
# Out:
# ...
#
# LightRAG log file: /home/alexey/test/mipt_mag_diploma/conference/rag_analyze/LightRAG/lightrag.log
#
# WARNING:root:>> Forcing workers=1 in uvicorn mode(Ignoring workers=2)
#
#     ╔══════════════════════════════════════════════════════════════╗
#     ║                LightRAG Server vv1.4.9.8/0251                ║
#     ║         Fast, Lightweight RAG Server Implementation          ║
#     ╚══════════════════════════════════════════════════════════════╝
#
#
# 📡 Server Configuration:
#     ├─ Host: 0.0.0.0
#     ├─ Port: 9621
#     ├─ Workers: 1
#     ├─ Timeout: 300
#     ├─ CORS Origins: *
#     ├─ SSL Enabled: False
#     ├─ Ollama Emulating Model: lightrag:latest
#     ├─ Log Level: INFO
#     ├─ Verbose Debug: False
#     ├─ API Key: Not Set
#     └─ JWT Auth: Disabled
#
# 📂 Directory Configuration:
#     ├─ Working Directory: /home/alexey/test/mipt_mag_diploma/conference/rag_analyze/LightRAG/rag_storage
# ...

# %% [markdown]
# Uploaded all PDF files from `data/for_rag.pdf`.

# %% [markdown]
# Even using small models it still heavy...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Waiting for 15 minutes...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5 tries later
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Graph tree
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Asked questions:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * Give information about K theory - Not found, text looks correct
# * Write proof of the Pieri-type formula - Relative document found, + 0.5
# * What does this formula mean? `v(h) < v(i) < v(l)` - Not found, text incorrect
# * Show Forbidden subsequences in chains in the k-Bruhat order - Relative document found, + 0.5
# * What is `∧i(S) · det(S∨) = ∧k−i(S∨)` - Not found, text looks correct
#
# First score - 1
#
# Now we ask:
# * Give information about K theory. Show needed document - Relative document found, + 0.5
# * What is `∧i(S) · det(S∨) = ∧k−i(S∨)`. Show needed document - Not found, text looks correct
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Second score - 1.5
